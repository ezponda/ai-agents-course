# %% [markdown]
# # Appendix F: Selected Resources
#
# Curated resources for going deeper. Quality over quantity.

# %% [markdown]
# ## Papers
#
# | Paper | Why it matters |
# |-------|----------------|
# | [ReAct: Reasoning and Acting in Language Models](https://arxiv.org/abs/2210.03629) | The foundation of how agents think and use tools |

# %% [markdown]
# ## Courses
#
# | Course | What you'll learn |
# |--------|-------------------|
# | [Building Effective AI Agents with n8n](https://dair-ai.thinkific.com/courses/agents-with-n8n) - DAIR.AI | Production-grade agents, evaluation, deployment |
# | [AI Agentic Design Patterns with AutoGen](https://www.deeplearning.ai/short-courses/ai-agentic-design-patterns-with-autogen/) - DeepLearning.AI | Agent patterns from Andrew Ng |

# %% [markdown]
# ## Blogs & Guides
#
# | Resource | Topic |
# |----------|-------|
# | [Building Effective Agents](https://www.anthropic.com/engineering/building-effective-agents) - Anthropic | Agent architecture and design |
# | [Advanced Tool Use](https://www.anthropic.com/engineering/advanced-tool-use) - Anthropic | Scaling to many tools |
# | [Prompt Engineering Guide](https://docs.anthropic.com/en/docs/build-with-claude/prompt-engineering/overview) - Anthropic | Official prompting docs |
# | [Prompt Engineering Guide](https://www.promptingguide.ai/) - DAIR.AI | Comprehensive prompting techniques |
